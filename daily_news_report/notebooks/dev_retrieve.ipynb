# %%
# tagesschau
# !poetry add deutschland -E tagesschau

from deutschland import tagesschau

print(tagesschau)
# Out:
# <module 'deutschland.tagesschau' from 'c:\\Users\\maschaefer\\Documents\\Weiterbildung\\Coding\\Python\\Daily_News_Report\\.venv\\lib\\site-packages\\deutschland\\tagesschau\\__init__.py'>

# %%
# News API with keyword
#!poetry add python-dotenv

import requests
import os
import pprint
from dotenv import load_dotenv
from datetime import datetime,timedelta

load_dotenv()
url = 'https://newsapi.org/v2/everything?'
parameters = {
    'q': '-Wetter OR -Musik OR -Verkehr OR -Fußball OR -Kommunen OR -heise+ OR -Spiel', # query phrase
    'pageSize': 10,  # maximum is 100
    'apiKey': os.getenv("NEWSAPI_API_KEY"), # your own API key
    'sortBy': 'popularity',
    # 'from': datetime.now().date(), 'to': datetime.now().date(),
    'from': datetime.now().date()-timedelta(days = 1), 'to': datetime.now().date(),
    'language': 'de',
    'domains': 'heise.de,stern.de,zeit.de,tagesschau.de',
    'excludeDomains': 'welt.de,waz.de'
}

response = requests.get(url, params = parameters)

response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Daniel Herbig',
#                'content': 'Zum Release von "EA Sports FC 24" schmeißt '
#                           'Electronic Arts den Vorgänger "FIFA 23" aus '
#                           'digitalen Stores wie Steam. "FIFA 23" kann also '
#                           'nicht mehr digital gekauft werden. "Auf Anfrage des '
#                           'Publishers i… [+1899 chars]',
#                'description': 'Zum Release von "EA Sports FC 24" hat '
#                               'Electronic Arts den Vorgänger "FIFA 23" aus '
#                               'digitalen Stores entfernen lassen – früher als '
#                               'gewöhnlich.',
#                'publishedAt': '2023-09-28T07:38:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': '"EA Sports FC 24": Electronic Arts schmeißt "FIFA 23" '
#                         'aus den Stores',
#                'url': 'https://www.heise.de/news/EA-Sports-FC-24-Electronic-Arts-schmeisst-FIFA-23-aus-den-Stores-9319671.html',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/5/0/7/ss_3d86cd3688bc0a4cf9f01c38383cfff9c3d06b8b.1920x1080-a691d0f7fa8c2b68.jpg'},
#               {'author': 'Daniel Herbig',
#                'content': 'Disney beginnt damit, Account-Sharing bei seinem '
#                           'Streaming-Dienst Disney+ zu erschweren. In den '
#                           'neuen Nutzungsbedingungen in Kanada ist es nun '
#                           'offiziell verboten, das eigene Passwort mit '
#                           'Personen auß… [+2369 chars]',
#                'description': 'Disney beginnt damit, gegen Account-Sharing '
#                               'vorzugehen. In Kanada ist es jetzt verboten, '
#                               'ein Passwort zu teilen – durchgesetzt wird das '
#                               'aber noch nicht.',
#                'publishedAt': '2023-09-28T07:53:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': 'Disney+: Account-Sharing außerhalb des Haushalts in '
#                         'Kanada jetzt verboten',
#                'url': 'https://www.heise.de/news/Disney-Account-Sharing-ausserhalb-des-Haushalts-in-Kanada-jetzt-verboten-9319787.html',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/5/6/9/shutterstock_1551002795-d5471ef1dfca1873.jpg'},
#               {'author': 'Gregor Honsel',
#                'content': 'Jährlich 5.000 Kilometer Reichweite könne ein '
#                           'Sattelschlepper durch integrierte Solarzellen '
#                           'hinzugewinnen, verspricht der Lastwagenhersteller '
#                           'Scania und das sogar in einem nördlichen Land wie '
#                           'Schwede… [+5511 chars]',
#                'description': 'Photovoltaik-Module auf elektrischen Lastwagen, '
#                               'Bussen oder Autos können die Reichweite '
#                               'verlängern. TR hat einen Experten nach '
#                               'konkreten Angaben gefragt.',
#                'publishedAt': '2023-09-28T05:30:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': 'Solarpaneele auf Dach und Seiten: Bei welchem '
#                         'Fahrzeug sich das lohnt',
#                'url': 'https://www.heise.de/hintergrund/Solarpaneele-auf-Dach-und-Seiten-Bei-welchem-Fahrzeug-sich-das-lohnt-9318809.html?wt_mc=rss.red.ho.ho.atom.beitrag.beitrag',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/0/3/5/b96fe426e772549d_org-4d51cb19dffc8b84.jpg'},
#               {'author': 'Jens Henneberg',
#                'content': 'Inhaltsverzeichnis\r\n'
#                           'Achtung! Meine Interpretation der 4-Tage-Woche '
#                           'könnte sich drastisch von der eines Vertreters '
#                           '(m/e/n/s/c/h) der Generation Z unterscheiden und '
#                           'das ist keineswegs wertend gemeint. … [+6294 chars]',
#                'description': 'Immer häufiger wird über die '
#                               '4-Tage-Arbeitswoche diskutiert. Wer den fünften '
#                               'Tag nur zum Faulenzen will, ist dabei falsch, '
#                               'zeigt der Bericht eines Freelancers.',
#                'publishedAt': '2023-09-28T05:30:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': 'Erfahrungen eines IT-Freelancers: Vier Tage Arbeit, '
#                         'fünf Tage Kopfzerbrechen',
#                'url': 'https://www.heise.de/meinung/Erfahrungen-eines-IT-Freelancers-Vier-Tage-Arbeit-fuenf-Tage-Kopfzerbrechen-9314096.html?wt_mc=rss.red.ho.ho.atom.beitrag.beitrag',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/0/7/5/3/7/Bildschirmfoto_2023-09-22_um_13.21.21-6412febb97aa7f53.png'},
#               {'author': 'Dr. Wolfgang Stieler',
#                'content': 'Laut Albert Einsteins allgemeiner '
#                           'Relativitätstheorie müssten alle Objekte, '
#                           'unabhängig von ihrer Masse oder Zusammensetzung, '
#                           'auf dieselbe Weise auf die Schwerkraft reagieren. '
#                           'Aber gilt dieses "Schwac… [+3715 chars]',
#                'description': 'Ein Forschungsteam am CERN hat erstmals '
#                               'untersucht, wie wie sich Anziehungskraft auf '
#                               'Anti-Wasserstoff im freien Fall auswirkt.',
#                'publishedAt': '2023-09-28T07:27:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': 'Antimaterie fällt genau wie gewöhnliche Materie',
#                'url': 'https://www.heise.de/news/Antimaterie-faellt-genau-wie-gewoehnliche-Materie-9319647.html',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/4/9/3/Alpha-Cern-2-201808-266_02-86b9c5248f24c309.jpg'},
#               {'author': 'Martin Kölling',
#                'content': 'Spätestens nach der diesjährigen Automesse IAA '
#                           'Mobility in München war auch dem letzten Autofan '
#                           'klar, dass Chinas Elektroauto-Offensive auch in '
#                           'Europa Chancen hat. Gleich mehrere Marken '
#                           'präsentierten… [+4344 chars]',
#                'description': 'Die Pandemie hat lange den Vormarsch '
#                               'chinesischer Autohersteller verdeckt. Nun '
#                               'bestätigen Messen und Experten, dass einige '
#                               'Firmen zu Challengern geworden sind.',
#                'publishedAt': '2023-09-28T06:30:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': 'Autoexperte hält chinesische E-Autos für besser als '
#                         'erste Teslas',
#                'url': 'https://www.heise.de/hintergrund/Autoexperte-haelt-chinesische-E-Autos-fuer-besser-als-erste-Teslas-9318738.html?wt_mc=rss.red.ho.ho.atom.beitrag.beitrag',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/0/9/9/9/7/nio-685e3030a4df08c2.png'},
#               {'author': 'Daniel Herbig',
#                'content': 'Jim Ryan hört als Chef von Sony Interactive '
#                           'Entertainment auf: Der Chef der Playstation-Sparte '
#                           'von Sony kündigte seinen Abschied in der Nacht zum '
#                           'Donnerstag an. Ryan will nur noch bis zum kommenden '
#                           'M… [+1861 chars]',
#                'description': 'Sonys Unterhaltungschef Jim Ryan verlässt das '
#                               'Unternehmen. Es gehe ihm dabei auch um die '
#                               'Work-Life-Balance, sagt der Brite.',
#                'publishedAt': '2023-09-28T07:09:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': 'Sony: Playstation-Chef Jim Ryan hört auf',
#                'url': 'https://www.heise.de/news/Sony-Playstation-Chef-Jim-Ryan-hoert-auf-9319617.html',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/4/7/7/Screenshot_2023-09-28_084744-5e25b95e211cf81e.png'},
#               {'author': 'Ben Schwan',
#                'content': 'Aus den USA, China und Kanada gibt es Berichte über '
#                           'spürbare Temperaturanstiege bei Apples iPhone 15 '
#                           'Pro und 15 Pro Max. Sie treten auf, wenn die Geräte '
#                           'geladen, aber auch wenn viele oder leistungsin… '
#                           '[+2739 chars]',
#                'description': 'Apples teuerste Handys kommen mit 3-nm-SoC und '
#                               'Titanhülle. Einige Nutzer melden '
#                               'Überhitzungsprobleme beim Laden. Ein Analyst '
#                               'glaubt zu wissen, woran es liegt.',
#                'publishedAt': '2023-09-28T07:22:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': 'iPhone 15 Pro und Pro Max: Berichte über '
#                         'Überhitzungsprobleme',
#                'url': 'https://www.heise.de/news/iPhone-15-Pro-und-Pro-Max-Berichte-ueber-Ueberhitzungsprobleme-9319283.html',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/3/0/0/Screenshot_2023-09-14_at_08.56.52-49f7647f7a6fbd7f.png'},
#               {'author': 'Dennis Schirrmacher',
#                'content': 'Derzeit haben es Angreifer auf Chrome abgesehen und '
#                           'nutzen eine Sicherheitslücke aus. Abgesicherte '
#                           'Versionen für Linux, macOS und Windows sind '
#                           'erschienen.\r\n'
#                           'Wer mit Chrome im Internet surft, sollte si… [+966 '
#                           'chars]',
#                'description': 'Google sichert seinen Webbrowser Chrome '
#                               'abermals gegen laufende Attacken ab.',
#                'publishedAt': '2023-09-28T07:29:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': 'Zehn Sicherheitslücken in Chrome geschlossen, eine '
#                         'wird bereits ausgenutzt',
#                'url': 'https://www.heise.de/news/Zehn-Sicherheitsluecken-in-Chrome-geschlossen-eine-wird-bereits-ausgenutzt-9319635.html',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/4/8/6/Chrome_Update_2023-cf6b1ea372934f01.png'},
#               {'author': 'Ben Schwan',
#                'content': 'Könnten 3D-gedruckte Häuser helfen, die Wohnungsnot '
#                           'zu bekämpfen? Beim thailändischen Unternehmen '
#                           'Concrete Products and Aggregate Co. Ltd. (CPAC), '
#                           'einer Tochter des größten Zementherstellers '
#                           'Thailand… [+2731 chars]',
#                'description': 'Leichtgewichtige Konstruktion, weniger Müll: '
#                               'Eine Tochter der Siam Cement Group hat das '
#                               'erste zweistöckige Fertighaus aus dem '
#                               '3D-Drucker gebaut.',
#                'publishedAt': '2023-09-28T05:00:00Z',
#                'source': {'id': None, 'name': 'heise online'},
#                'title': '3D-Druck: Betonfertighaus mit 2 Etagen – und '
#                         'ausgedrucktem Innenausbau',
#                'url': 'https://www.heise.de/hintergrund/3D-Druck-Betonfertighaus-mit-2-Etagen-und-ausgedrucktem-Innenausbau-9311844.html?wt_mc=rss.red.ho.ho.atom.beitrag.beitrag',
#                'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/0/6/3/3/4/Screenshot_2023-09-20_at_16.30.19-008ae40a605188aa.png'}],
#  'status': 'ok',
#  'totalResults': 363}

# %%
for i in response_json['articles']:
    date_string = i['publishedAt'].split("T")[0]
    date_object = datetime.strptime(date_string, '%Y-%m-%d').date()
    print(f"{i['title']} - Source {i['source']['name']} - URL: {i['url']}\n")
    print(f"{i['urlToImage']} \n {i['content']}")
# Out:
# "EA Sports FC 24": Electronic Arts schmeißt "FIFA 23" aus den Stores - Source heise online - URL: https://www.heise.de/news/EA-Sports-FC-24-Electronic-Arts-schmeisst-FIFA-23-aus-den-Stores-9319671.html
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/5/0/7/ss_3d86cd3688bc0a4cf9f01c38383cfff9c3d06b8b.1920x1080-a691d0f7fa8c2b68.jpg
#  Zum Release von "EA Sports FC 24" schmeißt Electronic Arts den Vorgänger "FIFA 23" aus digitalen Stores wie Steam. "FIFA 23" kann also nicht mehr digital gekauft werden. "Auf Anfrage des Publishers i… [+1899 chars]
# Disney+: Account-Sharing außerhalb des Haushalts in Kanada jetzt verboten - Source heise online - URL: https://www.heise.de/news/Disney-Account-Sharing-ausserhalb-des-Haushalts-in-Kanada-jetzt-verboten-9319787.html
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/5/6/9/shutterstock_1551002795-d5471ef1dfca1873.jpg
#  Disney beginnt damit, Account-Sharing bei seinem Streaming-Dienst Disney+ zu erschweren. In den neuen Nutzungsbedingungen in Kanada ist es nun offiziell verboten, das eigene Passwort mit Personen auß… [+2369 chars]
# Solarpaneele auf Dach und Seiten: Bei welchem Fahrzeug sich das lohnt - Source heise online - URL: https://www.heise.de/hintergrund/Solarpaneele-auf-Dach-und-Seiten-Bei-welchem-Fahrzeug-sich-das-lohnt-9318809.html?wt_mc=rss.red.ho.ho.atom.beitrag.beitrag
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/0/3/5/b96fe426e772549d_org-4d51cb19dffc8b84.jpg
#  Jährlich 5.000 Kilometer Reichweite könne ein Sattelschlepper durch integrierte Solarzellen hinzugewinnen, verspricht der Lastwagenhersteller Scania und das sogar in einem nördlichen Land wie Schwede… [+5511 chars]
# Erfahrungen eines IT-Freelancers: Vier Tage Arbeit, fünf Tage Kopfzerbrechen - Source heise online - URL: https://www.heise.de/meinung/Erfahrungen-eines-IT-Freelancers-Vier-Tage-Arbeit-fuenf-Tage-Kopfzerbrechen-9314096.html?wt_mc=rss.red.ho.ho.atom.beitrag.beitrag
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/0/7/5/3/7/Bildschirmfoto_2023-09-22_um_13.21.21-6412febb97aa7f53.png
#  Inhaltsverzeichnis
# Achtung! Meine Interpretation der 4-Tage-Woche könnte sich drastisch von der eines Vertreters (m/e/n/s/c/h) der Generation Z unterscheiden und das ist keineswegs wertend gemeint. … [+6294 chars]
# Antimaterie fällt genau wie gewöhnliche Materie - Source heise online - URL: https://www.heise.de/news/Antimaterie-faellt-genau-wie-gewoehnliche-Materie-9319647.html
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/4/9/3/Alpha-Cern-2-201808-266_02-86b9c5248f24c309.jpg
#  Laut Albert Einsteins allgemeiner Relativitätstheorie müssten alle Objekte, unabhängig von ihrer Masse oder Zusammensetzung, auf dieselbe Weise auf die Schwerkraft reagieren. Aber gilt dieses "Schwac… [+3715 chars]
# Autoexperte hält chinesische E-Autos für besser als erste Teslas - Source heise online - URL: https://www.heise.de/hintergrund/Autoexperte-haelt-chinesische-E-Autos-fuer-besser-als-erste-Teslas-9318738.html?wt_mc=rss.red.ho.ho.atom.beitrag.beitrag
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/0/9/9/9/7/nio-685e3030a4df08c2.png
#  Spätestens nach der diesjährigen Automesse IAA Mobility in München war auch dem letzten Autofan klar, dass Chinas Elektroauto-Offensive auch in Europa Chancen hat. Gleich mehrere Marken präsentierten… [+4344 chars]
# Sony: Playstation-Chef Jim Ryan hört auf - Source heise online - URL: https://www.heise.de/news/Sony-Playstation-Chef-Jim-Ryan-hoert-auf-9319617.html
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/4/7/7/Screenshot_2023-09-28_084744-5e25b95e211cf81e.png
#  Jim Ryan hört als Chef von Sony Interactive Entertainment auf: Der Chef der Playstation-Sparte von Sony kündigte seinen Abschied in der Nacht zum Donnerstag an. Ryan will nur noch bis zum kommenden M… [+1861 chars]
# iPhone 15 Pro und Pro Max: Berichte über Überhitzungsprobleme - Source heise online - URL: https://www.heise.de/news/iPhone-15-Pro-und-Pro-Max-Berichte-ueber-Ueberhitzungsprobleme-9319283.html
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/3/0/0/Screenshot_2023-09-14_at_08.56.52-49f7647f7a6fbd7f.png
#  Aus den USA, China und Kanada gibt es Berichte über spürbare Temperaturanstiege bei Apples iPhone 15 Pro und 15 Pro Max. Sie treten auf, wenn die Geräte geladen, aber auch wenn viele oder leistungsin… [+2739 chars]
# Zehn Sicherheitslücken in Chrome geschlossen, eine wird bereits ausgenutzt - Source heise online - URL: https://www.heise.de/news/Zehn-Sicherheitsluecken-in-Chrome-geschlossen-eine-wird-bereits-ausgenutzt-9319635.html
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/1/0/4/8/6/Chrome_Update_2023-cf6b1ea372934f01.png
#  Derzeit haben es Angreifer auf Chrome abgesehen und nutzen eine Sicherheitslücke aus. Abgesicherte Versionen für Linux, macOS und Windows sind erschienen.
# Wer mit Chrome im Internet surft, sollte si… [+966 chars]
# 3D-Druck: Betonfertighaus mit 2 Etagen – und ausgedrucktem Innenausbau - Source heise online - URL: https://www.heise.de/hintergrund/3D-Druck-Betonfertighaus-mit-2-Etagen-und-ausgedrucktem-Innenausbau-9311844.html?wt_mc=rss.red.ho.ho.atom.beitrag.beitrag
#
# https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/3/0/6/3/3/4/Screenshot_2023-09-20_at_16.30.19-008ae40a605188aa.png
#  Könnten 3D-gedruckte Häuser helfen, die Wohnungsnot zu bekämpfen? Beim thailändischen Unternehmen Concrete Products and Aggregate Co. Ltd. (CPAC), einer Tochter des größten Zementherstellers Thailand… [+2731 chars]
